# %%
from dataset import load_data
from models import EfficientNetModel
from helper_functions import train

# %%
# Loading data
train_loader, validation_loader = load_data()
# Out:
# Number of train examples: 3590
# Number of evaluation examples: 892
# Done loading data...

# %%
# creating a model
model = EfficientNetModel().model

# %%
# training the model
model = train(model, train_loader, validation_loader)
# Out:
# Device used: cuda
# Validation Loss: 0.5297, Validation Accuracy: 0.8400
# Epoch 1/10 done in 12.84749698638916 seconds ; Train Loss: 0.8426
# Validation Loss: 0.3694, Validation Accuracy: 0.8800
# Epoch 2/10 done in 10.401999711990356 seconds ; Train Loss: 0.5764
# Validation Loss: 0.3860, Validation Accuracy: 0.8700
# Epoch 3/10 done in 10.287999629974365 seconds ; Train Loss: 0.4711
# Validation Loss: 0.3842, Validation Accuracy: 0.8900
# Epoch 4/10 done in 10.43450117111206 seconds ; Train Loss: 0.3951
# Validation Loss: 0.3378, Validation Accuracy: 0.9100
# Epoch 5/10 done in 10.512502431869507 seconds ; Train Loss: 0.3388
# Validation Loss: 0.4183, Validation Accuracy: 0.8700
# Epoch 6/10 done in 10.575499534606934 seconds ; Train Loss: 0.3181
# Validation Loss: 0.3226, Validation Accuracy: 0.9100
# Epoch 7/10 done in 10.51199984550476 seconds ; Train Loss: 0.2919
# Validation Loss: 0.3334, Validation Accuracy: 0.9000
# Epoch 8/10 done in 10.39900016784668 seconds ; Train Loss: 0.2674
# Validation Loss: 0.3626, Validation Accuracy: 0.9100
# Epoch 9/10 done in 10.445000171661377 seconds ; Train Loss: 0.2429
# Validation Loss: 0.3241, Validation Accuracy: 0.9000
# Epoch 10/10 done in 10.610501289367676 seconds ; Train Loss: 0.2287
# Training time in Mins :  1.7838833014170328
# Train loss values per epoch:
# [0.8425914943218231, 0.5763762673983971, 0.4711358454078436, 0.3951185729820281, 0.3388470444828272, 0.31811880009869736, 0.29185742046684027, 0.26737462176242843, 0.24290050265241275, 0.22865486317314207]
