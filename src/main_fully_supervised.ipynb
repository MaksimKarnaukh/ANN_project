# %%
from dataset import load_data
from models import EfficientNetModel
from helper_functions import train

# %%
# Loading data
train_loader, validation_loader = load_data()
# Out:
# Number of train examples: 3590
# Number of evaluation examples: 892
# Done loading data...

# %%
# creating a model
model = EfficientNetModel().model

# %%
# training the model
model = train(model, train_loader, validation_loader, output_path='../output/fully_supervised/')
# Out:
# Device used: cuda
# Epoch 1/10 done in 12.31 seconds ; Train Loss: 0.7452
# Validation Loss: 0.5129, Validation Accuracy: 0.8600
# ---
# Epoch 2/10 done in 10.28 seconds ; Train Loss: 0.5212
# Validation Loss: 0.3102, Validation Accuracy: 0.9000
# ---
# Epoch 3/10 done in 10.83 seconds ; Train Loss: 0.4112
# Validation Loss: 0.3386, Validation Accuracy: 0.9000
# ---
# Epoch 4/10 done in 10.67 seconds ; Train Loss: 0.3598
# Validation Loss: 0.3840, Validation Accuracy: 0.8900
# ---
# Epoch 5/10 done in 10.14 seconds ; Train Loss: 0.3196
# Validation Loss: 0.3424, Validation Accuracy: 0.9000
# ---
# Epoch 6/10 done in 10.23 seconds ; Train Loss: 0.2820
# Validation Loss: 0.4671, Validation Accuracy: 0.8700
# ---
# Epoch 7/10 done in 10.14 seconds ; Train Loss: 0.2559
# Validation Loss: 0.3576, Validation Accuracy: 0.8900
# ---
# Epoch 8/10 done in 10.27 seconds ; Train Loss: 0.2334
# Validation Loss: 0.3278, Validation Accuracy: 0.9100
# ---
# Epoch 9/10 done in 10.22 seconds ; Train Loss: 0.2143
# Validation Loss: 0.3582, Validation Accuracy: 0.9100
# ---
# Epoch 10/10 done in 10.12 seconds ; Train Loss: 0.1988
# Validation Loss: 0.3622, Validation Accuracy: 0.9000
# ---
# Training time in Mins :  1.7534083167711894
# Train loss values per epoch:
# [0.745236317316691, 0.5211807883655032, 0.4112016726285219, 0.35982461638438207, 0.31964672353739537, 0.28202669692432714, 0.2559251035009289, 0.23335767537355423, 0.21434840087830606, 0.19882934590956816]
