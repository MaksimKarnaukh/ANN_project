# %%
from dataset import load_data, load_data_blurred
from models import EfficientNetModel
from helper_functions import train

# %%
# Loading data
train_loader, validation_loader = load_data_blurred()
# Out:
# Number of train examples: 17950
# Number of evaluation examples: 4460
# Done loading data...

# %%
# creating a model
model = EfficientNetModel(num_classes=5)

# %%
# training the model
trained_model = train(model.model, train_loader, validation_loader)
# Out:
# Device used: cuda
# Epoch 1/10 done in 22.52 seconds ; Train Loss: 0.2976
# Validation Loss: 0.0170, Validation Accuracy: 1.0000
# ---
# Epoch 2/10 done in 20.81 seconds ; Train Loss: 0.1785
# Validation Loss: 0.0114, Validation Accuracy: 1.0000
# ---
# Epoch 3/10 done in 20.76 seconds ; Train Loss: 0.1371
# Validation Loss: 0.0383, Validation Accuracy: 1.0000
# ---
# Epoch 4/10 done in 20.48 seconds ; Train Loss: 0.1118
# Validation Loss: 0.1418, Validation Accuracy: 1.0000
# ---
# Epoch 5/10 done in 20.84 seconds ; Train Loss: 0.0931
# Validation Loss: 0.1110, Validation Accuracy: 1.0000
# ---
# Epoch 6/10 done in 21.39 seconds ; Train Loss: 0.0828
# Validation Loss: 0.0396, Validation Accuracy: 1.0000
# ---
# Epoch 7/10 done in 21.13 seconds ; Train Loss: 0.0822
# Validation Loss: 0.1227, Validation Accuracy: 1.0000
# ---
# Epoch 8/10 done in 21.13 seconds ; Train Loss: 0.0732
# Validation Loss: 0.0865, Validation Accuracy: 0.9900
# ---
# Epoch 9/10 done in 21.34 seconds ; Train Loss: 0.0662
# Validation Loss: 0.0915, Validation Accuracy: 0.9900
# ---
# Epoch 10/10 done in 21.13 seconds ; Train Loss: 0.0654
# Validation Loss: 0.0838, Validation Accuracy: 0.9900
# ---
# Training time in Mins :  3.525641667842865
# Train loss values per epoch:
# [0.29762247382875595, 0.17846993585076315, 0.13707116151516863, 0.11184434208621895, 0.0930857157732693, 0.08282524137632198, 0.08220055863363852, 0.07318811688428707, 0.0661967649711334, 0.06540987577989239]

# %%
# drop gaussian kernel classifier from the model and add original classifier to end of feature extraction part.
model.replace_classifier(num_classes=15)
model.set_trainable(freeze_feature_extraction=True)

# %%
# Loading data
train_loader, validation_loader = load_data()
# Out:
# Number of train examples: 3590
# Number of evaluation examples: 892
# Done loading data...

# %%
# training the model
trained_model_original_classifier = train(model.model, train_loader, validation_loader)
# Out:
# Device used: cuda
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/10 done in 9.58 seconds ; Train Loss: 2.2666
# Validation Loss: 2.0336, Validation Accuracy: 0.3400
# ---
# Epoch 2/10 done in 9.08 seconds ; Train Loss: 2.1511
# Validation Loss: 1.9762, Validation Accuracy: 0.3500
# ---
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/10 done in 8.92 seconds ; Train Loss: 2.1339
# Validation Loss: 1.9461, Validation Accuracy: 0.3600
# ---
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\centu\PycharmProjects\ANN_project\venv\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 4/10 done in 8.98 seconds ; Train Loss: 2.0916
# Validation Loss: 1.9102, Validation Accuracy: 0.3600
# ---
# Epoch 5/10 done in 8.81 seconds ; Train Loss: 2.0673
# Validation Loss: 1.9103, Validation Accuracy: 0.3600
# ---
# Epoch 6/10 done in 8.75 seconds ; Train Loss: 2.0475
# Validation Loss: 1.8687, Validation Accuracy: 0.3900
# ---
# Epoch 7/10 done in 8.87 seconds ; Train Loss: 2.0352
# Validation Loss: 1.8622, Validation Accuracy: 0.4000
# ---
# Epoch 8/10 done in 8.91 seconds ; Train Loss: 2.0272
# Validation Loss: 1.8834, Validation Accuracy: 0.3500
# ---
# Epoch 9/10 done in 8.93 seconds ; Train Loss: 2.0114
# Validation Loss: 1.8455, Validation Accuracy: 0.3900
# ---
# Epoch 10/10 done in 8.97 seconds ; Train Loss: 2.0001
# Validation Loss: 1.8528, Validation Accuracy: 0.4000
# ---
# Training time in Mins :  1.4968666474024455
# Train loss values per epoch:
# [2.266559531291326, 2.151072079936663, 2.1339043743080564, 2.091620077689489, 2.067321312427521, 2.0474645793437958, 2.0351566587175642, 2.027158493796984, 2.011386744402073, 2.0000972797473273]
