# %%
from dataset import load_data, load_data_blurred
from models import EfficientNetModel
from helper_functions import train

# %%
# Loading data
train_loader, validation_loader = load_data_blurred()
# Out:
# Number of train examples: 17950
# Number of evaluation examples: 4460
# Done loading data...

# %%
# creating a model
model = EfficientNetModel(num_classes=5)

# %%
# training the model
trained_model = train(model.model, train_loader, validation_loader)
# Out:
# Device used: cuda
# Validation Loss: 0.0381, Validation Accuracy: 0.9900
# Epoch 1/10 done in 22.63149929046631 seconds ; Train Loss: 0.2961
# Validation Loss: 0.0085, Validation Accuracy: 1.0000
# Epoch 2/10 done in 20.24600124359131 seconds ; Train Loss: 0.1821
# Validation Loss: 0.0287, Validation Accuracy: 0.9900
# Epoch 3/10 done in 20.281498908996582 seconds ; Train Loss: 0.1348
# Validation Loss: 0.0478, Validation Accuracy: 0.9900
# Epoch 4/10 done in 20.196998596191406 seconds ; Train Loss: 0.1078
# Validation Loss: 0.0063, Validation Accuracy: 1.0000
# Epoch 5/10 done in 20.178500652313232 seconds ; Train Loss: 0.0916
# Validation Loss: 0.0082, Validation Accuracy: 1.0000
# Epoch 6/10 done in 20.294999837875366 seconds ; Train Loss: 0.0819
# Validation Loss: 0.0286, Validation Accuracy: 0.9900
# Epoch 7/10 done in 20.398998975753784 seconds ; Train Loss: 0.0753
# Validation Loss: 0.0012, Validation Accuracy: 1.0000
# Epoch 8/10 done in 20.359501361846924 seconds ; Train Loss: 0.0693
# Validation Loss: 0.0359, Validation Accuracy: 0.9800
# Epoch 9/10 done in 20.969500303268433 seconds ; Train Loss: 0.0627
# Validation Loss: 0.0022, Validation Accuracy: 1.0000
# Epoch 10/10 done in 20.179500818252563 seconds ; Train Loss: 0.0588
# Training time in Mins :  3.429050008455912
# Train loss values per epoch:
# [0.29609768040347517, 0.18210511949534217, 0.13483106813101473, 0.10781076704124484, 0.09163096437607014, 0.08189998235582352, 0.0753378249526276, 0.06932036097144814, 0.06274590407450512, 0.058788179858177164]

# %%
# drop gaussian kernel classifier from the model and add original classifier to end of feature extraction part.
